# %% [markdown]
# <a href="https://colab.research.google.com/github/seifeldinshadyy/flyrankai-Run-the-Starter-Notebooks-first-week-2/blob/main/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?
# *
#
# ## My Lane as an ML Task
#
# **Selected Lane:** Content Refresh Prioritization
#
# **Business Problem:**
# SEO teams manage thousands of webpages and need to identify which pages should be refreshed first to improve search performance and organic traffic.
#
# **Machine Learning Task Type:** Ranking
#
# This is a ranking problem because the goal is to order webpages from highest to lowest refresh priority based on their search performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
# ## Target or Proxy
#
# The model predicts a **Refresh Priority Score** for each webpage.
#
# Since there is no direct label indicating whether a page should be refreshed, a proxy target can be created using historical search performance, CTR, impressions, clicks, and ranking trends.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
# ## Success Metric
#
# Since this is a ranking problem, the model can be evaluated using ranking metrics such as:
#
# - Precision@K
# - NDCG (Normalized Discounted Cumulative Gain)
#
# These metrics measure how effectively the model ranks the highest-priority pages.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
# ## The Unit of Analysis
#
# Each row in the dataset represents a single webpage.
#
# The features describe that page's search performance, including clicks, impressions, CTR, average position, and other SEO-related metrics.
#
# The model produces one prediction for each webpage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
# ## Why ML Beats a Fixed Rule
#
# A fixed rule such as "refresh every page with CTR below 2%" ignores many important factors like impressions, clicks, average position, historical trends, and content type.
#
# Machine Learning can combine multiple features to estimate which pages are most likely to benefit from a content refresh, making better decisions than a simple handcrafted rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
#
#
#
# ________________________________________________________________
# - [x] Every section is complete.
# - [x] I named a valid ML task type.
# - [x] I defined a target or proxy.
# - [x] I chose a success metric.
# - [x] I showed the unit of analysis.
# - [x] I explained why ML is appropriate.
